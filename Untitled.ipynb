# %% [markdown]
# ## Жеребьевка
#
# на внутрилабораторные семинары

# %%
import datetime
import pandas as pd
import random
from datetime import timedelta

# %%
dti = pd.date_range("2023-02-03 14:00:00", periods=24, freq="w") #генератор дат на 24 недели
random.seed(12345)
m = 0
for i in range(22):
    if (m== 3) or (m == 11):
        m += 1
    if len(vist) == 0:
        vist = [
    'Ахмадеев Айдар Ринатович',
    'Байгильдин Самат Сагадатович',
    'Валова Яна Валерьевна',
    'Гизатуллина Алина Анваровна',
    'Каримов Денис Дмитриевич',
    'Каримов Денис Олегович',
    'Кудояров Эльдар Ренатович',
    'Мухаммадиева Гузель Фанисовна',
    'Репина Эльвира Фаридовна',
    'Смолянкин Денис Анатольевич',
    'Хуснутдинова Надежда Юрьевна',
    'Якупова Татьяна Георгиевна'
]
    if i == 0:
        n = 5
        print(dti[m] - timedelta(days=2), ' - ', vist[n])
        del vist[n]
        n = 7
        print(dti[m] - timedelta(days=2), ' - ', vist[n])
        del vist[n]
    else:
        n = random.randrange(len(vist))
        print(dti[m] - timedelta(days=2), ' - ', vist[n])
        del vist[n]
        n = random.randrange(len(vist))
        print(dti[m] - timedelta(days=2), ' - ', vist[n])
        del vist[n]
    m += 1
# Out:
# 2023-02-03 14:00:00  -  Каримов Денис Олегович
# 2023-02-03 14:00:00  -  Репина Эльвира Фаридовна
# 2023-02-10 14:00:00  -  Мухаммадиева Гузель Фанисовна
# 2023-02-10 14:00:00  -  Ахмадеев Айдар Ринатович
# 2023-02-17 14:00:00  -  Кудояров Эльдар Ренатович
# 2023-02-17 14:00:00  -  Якупова Татьяна Георгиевна
# 2023-03-03 14:00:00  -  Гизатуллина Алина Анваровна
# 2023-03-03 14:00:00  -  Валова Яна Валерьевна
# 2023-03-10 14:00:00  -  Смолянкин Денис Анатольевич
# 2023-03-10 14:00:00  -  Хуснутдинова Надежда Юрьевна
# 2023-03-17 14:00:00  -  Каримов Денис Дмитриевич
# 2023-03-17 14:00:00  -  Байгильдин Самат Сагадатович
# 2023-03-24 14:00:00  -  Каримов Денис Олегович
# 2023-03-24 14:00:00  -  Байгильдин Самат Сагадатович
# 2023-03-31 14:00:00  -  Репина Эльвира Фаридовна
# 2023-03-31 14:00:00  -  Кудояров Эльдар Ренатович
# 2023-04-07 14:00:00  -  Гизатуллина Алина Анваровна
# 2023-04-07 14:00:00  -  Смолянкин Денис Анатольевич
# 2023-04-14 14:00:00  -  Хуснутдинова Надежда Юрьевна
# ...
